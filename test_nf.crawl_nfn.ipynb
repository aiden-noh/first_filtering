# %%
import nfn_crawring as nf

CORP = ['063570', '한국전자금융']

# %%
# 한국전자금융 연간 손익계산서
nf.crawl_nfn(stock_code=CORP[0],
             type=nf.DataType.FS,
             subType=nf.FSType.IS,
             period=nf.Period.YEAR)
# Out:
# https://navercomp.wisereport.co.kr/v2/company/cF3002.aspx?cmp_cd=063570&frq=0&rpt=0&finGubun=MAIN&frqTyp=0&cn=&encparam=cE9KN0RLKy96ZmRnWnFnUWkzUkpodz09
#               account_nm      2018/12      2019/12      2020/12      2021/12  \
# 0                매출액(수익)  2944.234822  2789.171679  2258.706331  2383.643637
# 1                    *내수  2878.280000  2770.320000          NaN  2382.230000
# 2                    *수출    65.950000    58.440000          NaN     1.410000
# 3              ....제품매출액     0.604177     0.159183          NaN    31.180260
# 4              ....상품매출액   692.256471   506.510165   287.280901   302.577220
# ..                   ...          ...          ...          ...          ...
# 239             *희석주당순이익          NaN          NaN          NaN          NaN
# 240    *(지배주주지분)주당계속사업이익   702.000000    77.000000   165.000000   311.000000
# 241       *(지배주주지분)주당순이익   702.000000    89.000000   114.000000   306.000000
# ...

# %%
# 한국전자금융 분기 손익계산서
nf.crawl_nfn(stock_code=CORP[0],
             type=nf.DataType.FS,
             subType=nf.FSType.IS,
             period=nf.Period.QUARTER)
# Out:
# https://navercomp.wisereport.co.kr/v2/company/cF3002.aspx?cmp_cd=063570&frq=1&rpt=0&finGubun=MAIN&frqTyp=1&cn=&encparam=UnRSbFZkeXNMOWFreWNHNFVIZlBWUT09
#               account_nm     2022/09     2022/12     2023/03     2023/06  \
# 0                매출액(수익)  722.168679  847.499866  775.627411  892.707520
# 1                    *내수  722.170000         NaN         NaN  891.210000
# 2                    *수출         NaN         NaN         NaN    1.490000
# 3              ....제품매출액    4.105637   32.288882    8.534880    8.600161
# 4              ....상품매출액   69.751903  110.447931   82.861370  160.101081
# ..                   ...         ...         ...         ...         ...
# 239             *희석주당순이익         NaN         NaN         NaN         NaN
# 240    *(지배주주지분)주당계속사업이익   57.000000         NaN         NaN  127.000000
# 241       *(지배주주지분)주당순이익   57.000000         NaN         NaN  127.000000
# 242  *(지배주주지분)희석주당계속사업이익         NaN         NaN         NaN         NaN
# ...

# %%
# 한국전자금융 연간 재무상태표
nf.crawl_nfn(stock_code=CORP[0],
             type=nf.DataType.FS,
             subType=nf.FSType.BS,
             period=nf.Period.YEAR)
# Out:
# https://navercomp.wisereport.co.kr/v2/company/cF3002.aspx?cmp_cd=063570&frq=0&rpt=1&finGubun=MAIN&frqTyp=0&cn=&encparam=UzJOdmF6cjIyMEJhVUtFNWJ6dFFPQT09
#      account_nm        2018/12        2019/12        2020/12        2021/12  \
# 0          자산총계    4108.511522    4539.485248    4779.355936    4887.530411
# 1          유동자산    2376.606467    2202.974762    2107.826065    1895.404427
# 2      ....재고자산      37.304926      25.796422      38.566846      11.852604
# 3    ........상품      35.359430      24.977710      37.650820      11.852600
# 4    ........제품       0.393290            NaN            NaN            NaN
# ..          ...            ...            ...            ...            ...
# 246       수권주식수  100000.000000  100000.000000  100000.000000  100000.000000
# 247       1주당금액     500.000000     500.000000     500.000000     500.000000
# 248       발행주식수   34646.000000   34148.000000   34148.000000   34148.000000
# ...

# %%
# 한국전자금융 분기 재무상태표
nf.crawl_nfn(stock_code=CORP[0],
             type=nf.DataType.FS,
             subType=nf.FSType.BS,
             period=nf.Period.QUARTER)
# Out:
# https://navercomp.wisereport.co.kr/v2/company/cF3002.aspx?cmp_cd=063570&frq=1&rpt=1&finGubun=MAIN&frqTyp=1&cn=&encparam=ZVl2Smp3SUx0TWxNeGxsSXZVRm5wZz09
#      account_nm        2022/09        2022/12        2023/03        2023/06  \
# 0          자산총계    4786.461481    4978.971116    4967.224414    4999.863125
# 1          유동자산    1864.110869    1907.926225    1953.478573    1895.475551
# 2      ....재고자산      19.271134      14.765065      20.455892      21.094209
# 3    ........상품      19.271130      14.765070      20.455890      21.094210
# 4    ........제품            NaN            NaN            NaN            NaN
# ..          ...            ...            ...            ...            ...
# 246       수권주식수  100000.000000  100000.000000  100000.000000  100000.000000
# 247       1주당금액     500.000000     500.000000     500.000000     500.000000
# 248       발행주식수   34148.000000   34148.000000   34148.000000   34148.000000
# ...

# %%
# 한국전자금융 연간 현금흐름표
nf.crawl_nfn(stock_code=CORP[0],
             type=nf.DataType.FS,
             subType=nf.FSType.CF,
             period=nf.Period.YEAR)
# Out:
# https://navercomp.wisereport.co.kr/v2/company/cF3002.aspx?cmp_cd=063570&frq=0&rpt=2&finGubun=MAIN&frqTyp=0&cn=&encparam=SmszU0VGSzJRTGxWL3d4Tzh1VHNOUT09
#              account_nm      2018/12      2019/12      2020/12      2021/12  \
# 0          영업활동으로인한현금흐름   198.101716   516.091543   527.096523   662.753346
# 1             ....당기순이익   122.844050     9.697600    20.268460    90.414880
# 2    ....법인세비용차감전계속사업이익          NaN          NaN          NaN          NaN
# 3      ....현금유출이없는비용등가산   451.195860   677.758010   691.170160   717.282960
# 4          ........금융비용          NaN          NaN          NaN          NaN
# ..                  ...          ...          ...          ...          ...
# 307     연결범위변동으로인한현금의증가          NaN          NaN          NaN          NaN
# 308              환율변동효과    -0.072424     0.099782    -0.018040    -0.049413
# 309         현금및현금성자산의증가  -146.059453  -201.341863   -40.799688  -174.863560
# ...

# %%
# 한국전자금융 분기 현금흐름표
nf.crawl_nfn(stock_code=CORP[0],
             type=nf.DataType.FS,
             subType=nf.FSType.CF,
             period=nf.Period.QUARTER)
# Out:
# https://navercomp.wisereport.co.kr/v2/company/cF3002.aspx?cmp_cd=063570&frq=1&rpt=2&finGubun=MAIN&frqTyp=1&cn=&encparam=bmhrSEJqOThkSE0zVjRWeSswVENYZz09
#              account_nm      2022/09      2022/12      2023/03      2023/06  \
# 0          영업활동으로인한현금흐름   196.468496   165.176665    15.090131   195.806000
# 1             ....당기순이익    17.188890    46.311990    15.844030    39.327210
# 2    ....법인세비용차감전계속사업이익          NaN          NaN          NaN          NaN
# 3      ....현금유출이없는비용등가산   192.670580   224.608640   196.010360   210.778440
# 4          ........금융비용          NaN          NaN          NaN          NaN
# ..                  ...          ...          ...          ...          ...
# 307     연결범위변동으로인한현금의증가          NaN          NaN          NaN          NaN
# 308              환율변동효과     0.095420    -0.074358     0.035460    -0.171597
# 309         현금및현금성자산의증가  -124.196574  -125.454189    22.354094   -69.439493
# ...

# %%
# 한국전자금융 연간 수익성 투자지표
nf.crawl_nfn(stock_code=CORP[0],
             type=nf.DataType.IV,
             subType=nf.IVType.PROFIT,
             period=nf.Period.YEAR)
# Out:
# https://navercomp.wisereport.co.kr/v2/company/cF4002.aspx?cmp_cd=063570&frq=0&rpt=1&finGubun=MAIN&frqTyp=0&cn=&encparam=ay9rb0E3a3BvZzJQMGJyakl3d3Bldz09
#        account_nm      2018/12      2019/12      2020/12      2021/12  \
# 0          매출총이익률    79.780000    83.632000    90.409000    88.657000
# 1       매출총이익＜당기＞  2348.899546  2332.629187  2042.071070  2113.267473
# 2         매출액＜당기＞  2944.234822  2789.171679  2258.706331  2383.643637
# 3           영업이익률     8.462000     5.583000     6.279000     5.994000
# 4        영업이익＜당기＞   249.126770   155.707643   141.824204   142.876328
# 5         매출액＜당기＞  2944.234822  2789.171679  2258.706331  2383.643637
# 6            순이익률     4.172000     0.348000     0.897000     3.793000
# 7       당기순이익＜당기＞   122.844050     9.697604    20.268465    90.414877
# 8         매출액＜당기＞  2944.234822  2789.171679  2258.706331  2383.643637
# 9       EBITDA마진율    17.923000    22.141000    28.974000    29.921000
# ...

# %%
# 한국전자금융 분기 수익성 투자지표
nf.crawl_nfn(stock_code=CORP[0],
             type=nf.DataType.IV,
             subType=nf.IVType.PROFIT,
             period=nf.Period.QUARTER)
# Out:
# https://navercomp.wisereport.co.kr/v2/company/cF4002.aspx?cmp_cd=063570&frq=1&rpt=1&finGubun=MAIN&frqTyp=1&cn=&encparam=K0lsNmJOdmFVQ3BIdGkrK2xjRGNrUT09
#        account_nm      2022/09      2022/12      2023/03      2023/06  \
# 0          매출총이익률    91.847000    85.405000    90.320000    83.546000
# 1       매출총이익＜당기＞   663.289710   723.808740   700.548780   745.819815
# 2         매출액＜당기＞   722.168679   847.499866   775.627411   892.707520
# 3           영업이익률     6.059000     7.487000     6.489000     8.282000
# 4        영업이익＜당기＞    43.754863    63.450823    50.328954    73.936257
# 5         매출액＜당기＞   722.168679   847.499866   775.627411   892.707520
# 6            순이익률     2.380000     5.465000     2.043000     4.405000
# 7       당기순이익＜당기＞    17.188888    46.311990    15.844030    39.327205
# 8         매출액＜당기＞   722.168679   847.499866   775.627411   892.707520
# 9       EBITDA마진율    27.670000    25.114000    26.079000    25.542000
# ...

# %%
# 한국전자금융 연간 성장성 투자지표
nf.crawl_nfn(stock_code=CORP[0],
             type=nf.DataType.IV,
             subType=nf.IVType.GROWTH,
             period=nf.Period.YEAR)
# Out:
# https://navercomp.wisereport.co.kr/v2/company/cF4002.aspx?cmp_cd=063570&frq=0&rpt=2&finGubun=MAIN&frqTyp=0&cn=&encparam=UjNqTkJsVEdveXg3bGZvRGx2Wjkzdz09
#    account_nm      2018/12      2019/12      2020/12      2021/12      2022/12
# 0      매출액증가율    22.145000    -5.267000   -19.019000     5.531000    21.207000
# 1     매출액＜전기＞  2410.437357  2944.234822  2789.171679  2258.706331  2383.643637
# 2     매출액＜당기＞  2944.234822  2789.171679  2258.706331  2383.643637  2889.132455
# 3     영업이익증가율    18.316000   -37.499000    -8.916000     0.742000    32.220000
# 4    영업이익＜전기＞   210.561320   249.126770   155.707643   141.824204   142.876328
# 5    영업이익＜당기＞   249.126770   155.707643   141.824204   142.876328   188.910947
# 6      순이익증가율   -25.237000   -92.106000   109.005000   346.086000    -4.166000
# 7   당기순이익＜전기＞   164.310818   122.844050     9.697604    20.268465    90.414877
# 8   당기순이익＜당기＞   122.844050     9.697604    20.268465    90.414877    86.648562
# ...

# %%
# 한국전자금융 분기 성장성 투자지표
nf.crawl_nfn(stock_code=CORP[0],
             type=nf.DataType.IV,
             subType=nf.IVType.GROWTH,
             period=nf.Period.QUARTER)
# Out:
# https://navercomp.wisereport.co.kr/v2/company/cF4002.aspx?cmp_cd=063570&frq=1&rpt=2&finGubun=MAIN&frqTyp=1&cn=&encparam=dHYxUVpmbThVWXZVYi9idGdWNVBqdz09
#    account_nm      2022/09      2022/12      2023/03      2023/06      2023/09
# 0      매출액증가율    -0.370000    17.355000    -8.481000    15.095000     5.394000
# 1     매출액＜전기＞   724.847679   722.168679   847.499866   775.627411   892.707520
# 2     매출액＜당기＞   722.168679   847.499866   775.627411   892.707520   940.858114
# 3     영업이익증가율   -23.132000    45.014000   -20.680000    46.906000   -11.967000
# 4    영업이익＜전기＞    56.921969    43.754863    63.450823    50.328954    73.936257
# 5    영업이익＜당기＞    43.754863    63.450823    50.328954    73.936257    65.088423
# 6      순이익증가율   -21.071000   169.430000   -65.788000   148.215000   -60.374000
# 7   당기순이익＜전기＞    21.777748    17.188888    46.311990    15.844030    39.327205
# 8   당기순이익＜당기＞    17.188888    46.311990    15.844030    39.327205    15.583780
# ...

# %%
# 한국전자금융 연간 안정성 투자지표
nf.crawl_nfn(stock_code=CORP[0],
             type=nf.DataType.IV,
             subType=nf.IVType.STABILITY,
             period=nf.Period.YEAR)
# Out:
# https://navercomp.wisereport.co.kr/v2/company/cF4002.aspx?cmp_cd=063570&frq=0&rpt=3&finGubun=MAIN&frqTyp=0&cn=&encparam=dHYxUVpmbThVWXZVYi9idGdWNVBqdz09
#    account_nm      2018/12      2019/12      2020/12      2021/12      2022/12
# 0        부채비율   149.027000   183.085000   203.318000   193.538000   183.253000
# 1        부채총계  2458.683993  2935.906969  3203.662175  3222.487765  3221.187275
# 2        자본총계  1649.827529  1603.578279  1575.693761  1665.042647  1757.783841
# 3      유동부채비율   114.368000   133.468000   143.300000   135.963000   138.855000
# 4        유동부채  1886.874115  2140.270689  2257.971364  2263.835856  2440.763296
# 5        자본총계  1649.827529  1603.578279  1575.693761  1665.042647  1757.783841
# 6     비유동부채비율    34.659000    49.616000    60.017000    57.575000    44.398000
# 7       비유동부채   571.809878   795.636280   945.690811   958.651909   780.423979
# 8        자본총계  1649.827529  1603.578279  1575.693761  1665.042647  1757.783841
# ...

# %%
# 한국전자금융 분기 안정성 투자지표
nf.crawl_nfn(stock_code=CORP[0],
             type=nf.DataType.IV,
             subType=nf.IVType.STABILITY,
             period=nf.Period.QUARTER)
# Out:
# https://navercomp.wisereport.co.kr/v2/company/cF4002.aspx?cmp_cd=063570&frq=1&rpt=3&finGubun=MAIN&frqTyp=1&cn=&encparam=M3lzMmc5WjByd3hvUlFkZEtkd1lFZz09
#    account_nm      2022/09      2022/12      2023/03      2023/06      2023/09
# 0        부채비율   184.284000   183.253000   185.221000   183.166000   204.150000
# 1        부채총계  3102.769190  3221.187275  3225.688802  3234.163595  3649.319440
# 2        자본총계  1683.692291  1757.783841  1741.535612  1765.699530  1787.564764
# 3      유동부채비율   143.314000   138.855000   141.815000   140.134000   162.411000
# 4        유동부채  2412.962918  2440.763296  2469.756704  2474.352107  2903.198614
# 5        자본총계  1683.692291  1757.783841  1741.535612  1765.699530  1787.564764
# 6     비유동부채비율    40.970000    44.398000    43.406000    43.032000    41.740000
# 7       비유동부채   689.806272   780.423979   755.932098   759.811490   746.120826
# 8        자본총계  1683.692291  1757.783841  1741.535612  1765.699530  1787.564764
# ...

# %%
# 한국전자금융 연간 활동성 투자지표
nf.crawl_nfn(stock_code=CORP[0],
             type=nf.DataType.IV,
             subType=nf.IVType.ACTIVITY,
             period=nf.Period.YEAR)
# Out:
# https://navercomp.wisereport.co.kr/v2/company/cF4002.aspx?cmp_cd=063570&frq=0&rpt=4&finGubun=MAIN&frqTyp=0&cn=&encparam=MGNoQlNKZnpXVXFaeGZ0emRONU9IZz09
#           account_nm      2018/12      2019/12      2020/12      2021/12  \
# 0             총자산회전율     0.743370     0.645040     0.484760     0.493160
# 1            매출액(수익)  2944.234822  2789.171679  2258.706331  2383.643637
# 2           자산총계＜전기＞  3812.855626  4108.511522  4539.485248  4779.355936
# 3           자산총계＜당기＞  4108.511522  4539.485248  4779.355936  4887.530411
# 4            자기자본회전율     1.828210     1.714620     1.420900     1.471050
# 5            매출액＜당기＞  2944.234822  2789.171679  2258.706331  2383.643637
# 6           자본총계＜당기＞  1649.827529  1603.578279  1575.693761  1665.042647
# 7           자본총계＜전기＞  1571.063930  1649.827529  1603.578279  1575.693761
# 8           순운전자본회전율  -155.258060   143.016680    38.561780    49.566640
# 9            매출액＜당기＞  2944.234822  2789.171679  2258.706331  2383.643637
# ...

# %%
# 한국전자금융 분기 활동성 투자지표
nf.crawl_nfn(stock_code=CORP[0],
             type=nf.DataType.IV,
             subType=nf.IVType.ACTIVITY,
             period=nf.Period.QUARTER)
# Out:
# https://navercomp.wisereport.co.kr/v2/company/cF4002.aspx?cmp_cd=063570&frq=1&rpt=4&finGubun=MAIN&frqTyp=1&cn=&encparam=TDl6TDFweDFqMzhoS1pTb0xoSmExdz09
#           account_nm      2022/09      2022/12      2023/03      2023/06  \
# 0             총자산회전율     0.147720     0.173570     0.155960     0.179130
# 1            매출액(수익)   722.168679   847.499866   775.627411   892.707520
# 2           자산총계＜전기＞  4991.244306  4786.461481  4978.971116  4967.224414
# 3           자산총계＜당기＞  4786.461481  4978.971116  4967.224414  4999.863125
# 4            자기자본회전율     0.430210     0.492520     0.443300     0.509060
# 5            매출액＜당기＞   722.168679   847.499866   775.627411   892.707520
# 6           자본총계＜당기＞  1683.692291  1757.783841  1741.535612  1765.699530
# 7           자본총계＜전기＞  1673.580362  1683.692291  1757.783841  1741.535612
# 8           순운전자본회전율    13.468180    15.174380     5.601400     4.565380
# 9            매출액＜당기＞   722.168679   847.499866   775.627411   892.707520
# ...

# %%
# 한국전자금융 연간 가치분석 투자지표
nf.crawl_nfn(stock_code=CORP[0],
             type=nf.DataType.IV,
             subType=nf.IVType.VALUEABLE,
             period=nf.Period.YEAR)
# Out:
# https://navercomp.wisereport.co.kr/v2/company/cF4002.aspx?cmp_cd=063570&frq=0&rpt=5&finGubun=MAIN&frqTyp=0&cn=&encparam=ZjdhWXV2RTlsamFPNjc0TXFIQlloQT09
#                  account_nm       2018/12       2019/12       2020/12  \
# 0                       EPS  6.208630e+02  7.814067e+01  1.012457e+02
# 1             당기순이익(지배)＜당기＞  2.104047e+02  2.683999e+01  3.457311e+01
# 2          보통주수정평균발행주식수＜당기＞  3.388906e+07  3.434829e+07  3.414773e+07
# 3          우선주수정평균발행주식수＜당기＞  0.000000e+00  0.000000e+00  0.000000e+00
# 4                       BPS  5.192379e+03  5.096289e+03  5.106150e+03
# 5              자본총계(지배)＜당기＞  1.574868e+03  1.545723e+03  1.548714e+03
# 6   보통주수정기말발행주식수(자사주차감)＜당기＞  3.033037e+07  3.033037e+07  3.033037e+07
# 7   우선주수정기말발행주식수(자사주차감)＜당기＞  0.000000e+00  0.000000e+00  0.000000e+00
# 8                       CPS  5.845595e+02  1.502525e+03  1.543577e+03
# 9              영업활동현금흐름＜당기＞  1.981017e+02  5.160915e+02  5.270965e+02
# ...

# %%
# 한국전자금융 분기 가치분석 투자지표
nf.crawl_nfn(stock_code=CORP[0],
             type=nf.DataType.IV,
             subType=nf.IVType.VALUEABLE,
             period=nf.Period.QUARTER)
# Out:
# https://navercomp.wisereport.co.kr/v2/company/cF4002.aspx?cmp_cd=063570&frq=1&rpt=5&finGubun=MAIN&frqTyp=1&cn=&encparam=RlR0QVdUR1U0clVwN1RoQno4bFVzQT09
#                  account_nm       2022/09       2022/12       2023/03  \
# 0                       EPS  5.106890e+01  1.332154e+02  4.664622e+01
# 1             당기순이익(지배)＜당기＞  1.743887e+01  4.549003e+01  1.592862e+01
# 2          보통주수정평균발행주식수＜당기＞  3.414773e+07  3.414773e+07  3.414773e+07
# 3          우선주수정평균발행주식수＜당기＞  0.000000e+00  0.000000e+00  0.000000e+00
# 4                       BPS  5.505043e+03  5.746513e+03  5.693221e+03
# 5              자본총계(지배)＜당기＞  1.669700e+03  1.742938e+03  1.726775e+03
# 6   보통주수정기말발행주식수(자사주차감)＜당기＞  3.033037e+07  3.033037e+07  3.033037e+07
# 7   우선주수정기말발행주식수(자사주차감)＜당기＞  0.000000e+00  0.000000e+00  0.000000e+00
# 8                       CPS  5.753487e+02  4.837120e+02  4.419073e+01
# 9              영업활동현금흐름＜당기＞  1.964685e+02  1.651767e+02  1.509013e+01
# ...
